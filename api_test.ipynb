# %%
path  = '/content/drive/MyDrive/SER- Project/EffNetZero '
from tensorflow import keras
model = keras.models.load_model('/content/drive/MyDrive/SER- Project/EffNetZero ')

# %%
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_layer (InputLayer)    [(None, 256, 256, 3)]     0
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling2d_3   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 6)                 7686
#
#  softmax_float32 (Activation  (None, 6)                0
#  )
#
# ...
# Total params: 4,057,257
# Trainable params: 7,686
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Testing Data pipeline for API
from tensorflow import keras  
import json
import os
import librosa
import numpy as np 
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
def classify(dir_path): 
  input_list = []
  for filename in os.listdir(dir_path):
      image_path =  os.path.join(dir_path,filename)
      img =  prep_for_model(image_path)
      input_list.append(img)
  input_list=  np.array(input_list)
  output_layer =model.predict(input_list)
  output_list = translate_to_Emotion(output_layer)
      
  return output_list

    # return  result of classification  
    



def prep_fn(img): #prepare for NN
    img = img.astype(np.float32) / 255.0 # [0,1]
    # img = (img - 0.5) * 2  # [0 -0.5 , 1 - 0.5] => [-0.5, 0.5] * 2 => [-1,1]
    return img

def prep_for_model(img_path,img_size = (256,256,3)):
    img = img_to_array(load_img(img_path,grayscale=False,color_mode='rgb',target_size=img_size,interpolation='bilinear'))
    img = prep_fn(img)
    return img

def translate_to_Emotion(list_of_res):
  emo_list = []
  for output_layer in list_of_res:
      emo_dict = {1: 'Neutral' , 2 : 'Angry'  , 3:'Happy' ,4 : 'Sad' , 5: 'Frustrated',0 :'None' }
      output_layer =  output_layer.tolist()
      index =  output_layer.index(max(output_layer))
      emo_list.append(emo_dict[index])
  return emo_list

# %%
# spectrogram_path = '/content/drive/MyDrive/SER- Project/spectogram'
# results =  classify(spectrogram_path)
# print(results)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ['Frustrated', 'Frustrated', 'Happy', 'Happy', 'Frustrated', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Frustrated', 'Frustrated', 'Happy', 'Frustrated']

# %%
  
import tensorflow 
print(tensorflow.__version__)
# Out:
# 2.8.2
